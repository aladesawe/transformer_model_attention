# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np
from util import pos_enc_matrix


# Plot the positional encoding matrix
pos_matrix = pos_enc_matrix(L=2048, d=512)
assert pos_matrix.shape == (2048, 512)
plt.pcolormesh(pos_matrix, cmap='RdBu')
plt.xlabel('Depth')
plt.ylabel('Position')
plt.colorbar()
plt.show()

with open("posenc-2048-512.pickle", "wb") as fp:
    pickle.dump(pos_matrix, fp)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 import matplotlib.pyplot as plt
#       3 import numpy as np
# ----> 4 from util import pos_enc_matrix
#       7 # Plot the positional encoding matrix
#       8 pos_matrix = pos_enc_matrix(L=2048, d=512)
#
# File ~/personal/b_transformer/util.py:30
#      26     P[:, 1::2] = np.cos(args)
#      27     return P
# ---> 30 PositionalEmbedding.pos_enc_matrix = pos_enc_matrix
#      32 class PositionalEmbedding(tf.keras.layers.Layer):
#      33     """
#      34     Positional embedding layer. Assume tokenized input, transform into embedding and returns positional-encoded output.
#      35     """
#
# NameError: name 'PositionalEmbedding' is not defined

# %% [markdown]
# ## Separate the sine curves from teh cosine curves

# %%
import pickle
import matplotlib.pyplot as plt
import numpy as np

with open("posenc-2048-512.pickle", "rb") as fp:
    pos_matrix = pickle.load(fp)

assert pos_matrix.shape == (2048, 512)
# Plot the positional encoding matrix, alternative way
plt.pcolormesh(np.hstack([pos_matrix[:, ::2], pos_matrix[:, 1::2]]), cmap='RdBu')
plt.xlabel('Depth')
plt.ylabel('Position')
plt.colorbar()
plt.show()

# %%
# Plot of high and low freq (different depth) depth in the matrix
import pickle
import matplotlib.pyplot as plt
import numpy as np

with open("posenc-2048-512.pickle", "rb") as fp:
    pos_matrix = pickle.load(fp)

assert pos_matrix.shape == (2048, 512)
plt.plot(pos_matrix[:, 155], label="high freq")
plt.plot(pos_matrix[:, 300], label="low freq")
plt.legend()
plt.show()

# %%
# Visualize one "position" of the matrix
import pickle
import matplotlib.pyplot as plt
import numpy as np

with open("posenc-2048-512.pickle", "rb") as fp:
    pos_matrix = pickle.load(fp)

assert pos_matrix.shape == (2048, 512)
plt.plot(pos_matrix[100], alpha=0.66, color="red", label="position 100")
plt.legend()
plt.show()

# %%
# Compare two encoding vectors
# Dot-product of two normalized vectors is 1
import pickle
import matplotlib.pyplot as plt
import numpy as np

with open("posenc-2048-512.pickle", "rb") as fp:
    pos_matrix = pickle.load(fp)

assert pos_matrix.shape == (2048, 512)
# Show the dot product between different normalized positional vectors
pos_matrix /= np.linalg.norm(pos_matrix, axis=1, keepdims=True)
p = pos_matrix[789] # all vectors compare to vector at position 789
dots = pos_matrix @ p
plt.plot(dots)
plt.ylim([0, 1])
plt.show()
